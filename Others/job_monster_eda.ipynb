# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../DATA/monster_com-job_sample.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of                         country country_code date_added has_expired  \
# 0      United States of America           US        NaN          No
# 1      United States of America           US        NaN          No
# 2      United States of America           US        NaN          No
# 3      United States of America           US        NaN          No
# 4      United States of America           US        NaN          No
# ...                         ...          ...        ...         ...
# 21995  United States of America           US        NaN          No
# 21996  United States of America           US        NaN          No
# 21997  United States of America           US        NaN          No
# 21998  United States of America           US        NaN          No
# 21999  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# ...

# %%
df.shape
# Out:
# (22000, 14)

# %%
df.isna().sum()
# Out:
# country                0
# country_code           0
# date_added         21878
# has_expired            0
# job_board              0
# job_description        0
# job_title              0
# job_type            1628
# location               0
# organization        6867
# page_url               0
# salary             18554
# sector              5194
# uniq_id                0
# dtype: int64

# %%
df['job_type'].head
# Out:
# <bound method NDFrame.head of 0         Full Time Employee
# 1                  Full Time
# 2        Full Time, Employee
# 3                  Full Time
# 4         Full Time Employee
#                 ...
# 21995              Full Time
# 21996              Full Time
# 21997              Full Time
# 21998     Full Time Employee
# 21999              Full Time
# Name: job_type, Length: 22000, dtype: object>

# %%
df['organization'].head
# Out:
# <bound method NDFrame.head of 0                                                   NaN
# 1                               Printing and Publishing
# 2                       Personal and Household Services
# 3                                      Altec Industries
# 4                                                Retail
#                               ...
# 21995                                               NaN
# 21996    Construction - Residential & Commercial/Office
# 21997                                               NaN
# 21998                         Jernberg Industries, Inc.
# 21999                                               NaN
# Name: organization, Length: 22000, dtype: object>

# %%
# Drop Salary and date_added

df.drop(columns=['date_added','salary'], axis=1, inplace=True)

# %%
df
# Out:
#                         country country_code has_expired         job_board  \
# 0      United States of America           US          No  jobs.monster.com
# 1      United States of America           US          No  jobs.monster.com
# 2      United States of America           US          No  jobs.monster.com
# 3      United States of America           US          No  jobs.monster.com
# 4      United States of America           US          No  jobs.monster.com
# ...                         ...          ...         ...               ...
# 21995  United States of America           US          No  jobs.monster.com
# 21996  United States of America           US          No  jobs.monster.com
# 21997  United States of America           US          No  jobs.monster.com
# 21998  United States of America           US          No  jobs.monster.com
# 21999  United States of America           US          No  jobs.monster.com
#
#                                          job_description  \
# ...

# %%
df.isna().sum()
# Out:
# country               0
# country_code          0
# has_expired           0
# job_board             0
# job_description       0
# job_title             0
# job_type           1628
# location              0
# organization       6867
# page_url              0
# sector             5194
# uniq_id               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          22000 non-null  object
#  1   country_code     22000 non-null  object
#  2   has_expired      22000 non-null  object
#  3   job_board        22000 non-null  object
#  4   job_description  22000 non-null  object
#  5   job_title        22000 non-null  object
#  6   job_type         20372 non-null  object
#  7   location         22000 non-null  object
#  8   organization     15133 non-null  object
#  9   page_url         22000 non-null  object
#  10  sector           16806 non-null  object
#  11  uniq_id          22000 non-null  object
# dtypes: object(12)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#                          country country_code has_expired         job_board  \
# count                      22000        22000       22000             22000
# unique                         1            1           1                 1
# top     United States of America           US          No  jobs.monster.com
# freq                       22000        22000       22000             22000
#
#                                           job_description job_title  \
# count                                               22000     22000
# unique                                              18744     18759
# top     12N Horizontal Construction Engineers Job Desc...   Monster
# freq                                                  104       318
#
#          job_type    location         organization  \
# count       20372       22000                15133
# unique         39        8423                  738
# top     Full Time  Dallas, TX  Healthcare Services
# ...

# %%
df['organization'].value_counts()
# Out:
# organization
# Healthcare Services                                                                                        1919
# All                                                                                                        1158
# Retail                                                                                                     1081
# Other/Not Classified                                                                                       1048
# Manufacturing - Other                                                                                       885
#                                                                                                            ...
# Printing and Publishing Architectural and Design ServicesConstruction - Residential & Commercial/Office       1
# Construction - Industrial Facilities and InfrastructureManufacturing - Other                                  1
# ...

# %%
df['job_type'].value_counts()
# Out:
# job_type
# Full Time                                        6757
# Full Time Employee                               6617
# Full Time, Employee                              3360
# Full Time Temporary/Contract/Project             1062
# Full Time, Temporary/Contract/Project             533
# Full Time , Employee                              406
# Part Time Employee                                382
# Part Time                                         329
# Part Time, Employee                               196
# Temporary/Contract/Project                        193
# Employee                                          147
# Full Time / Employee                              121
# Full Time , Temporary/Contract/Project             56
# Part Time, Temporary/Contract/Project              34
# Per Diem, Employee                                 29
# Per Diem                                           22
# Job Type Full Time Employee                        19
# ...

# %%
df_mini = df.iloc[:5,]

# %%
df_mini
# Out:
#                     country country_code has_expired         job_board  \
# 0  United States of America           US          No  jobs.monster.com
# 1  United States of America           US          No  jobs.monster.com
# 2  United States of America           US          No  jobs.monster.com
# 3  United States of America           US          No  jobs.monster.com
# 4  United States of America           US          No  jobs.monster.com
#
#                                      job_description  \
# 0  TeamSoft is seeing an IT Support Specialist to...
# 1  The Wisconsin State Journal is seeking a flexi...
# 2  Report this job About the Job DePuy Synthes Co...
# 3  Why Join Altec? If you’re considering a career...
# 4  Position ID#  76162 # Positions  1 State  CT C...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# ...
